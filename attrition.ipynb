# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# ...

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
attributes = ['Age', 'JobInvolvement', 'JobSatisfaction', 'DistanceFromHome', 'YearsInCurrentRole',
              'YearsSinceLastPromotion', 'WorkLifeBalance', 'OverTime', 'JobRole', 'TrainingTimesLastYear']

# Create X_df using your selected columns
X_df = attrition_df[attributes]

# Show the data types for X_df
X_df.dtypes
# Out:
# Age                         int64
# JobInvolvement              int64
# JobSatisfaction             int64
# DistanceFromHome            int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# WorkLifeBalance             int64
# OverTime                   object
# JobRole                    object
# TrainingTimesLastYear       int64
# dtype: object

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_numeric = pd.get_dummies(X_df).astype(int)
X_numeric.head()
# Out:
#    Age  JobInvolvement  JobSatisfaction  DistanceFromHome  YearsInCurrentRole  \
# 0   41               3                4                 1                   4
# 1   49               2                2                 8                   7
# 2   37               2                3                 2                   0
# 3   33               3                3                 3                   7
# 4   27               3                2                 2                   2
#
#    YearsSinceLastPromotion  WorkLifeBalance  TrainingTimesLastYear  \
# 0                        0                1                      0
# 1                        1                3                      3
# 2                        0                3                      3
# 3                        3                3                      3
# 4                        2                3                      3
#
#    OverTime_No  OverTime_Yes  JobRole_Healthcare Representative  \
# ...

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_numeric, y_df, test_size=0.2, random_state=42)

# %%
# Create a StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder
dept_OHE = OneHotEncoder(sparse=False)

# Fit the encoder to the training data
dept_OHE.fit(y_train[['Department']])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_encoded = dept_OHE.transform(y_train[['Department']])
y_test_encoded = dept_OHE.transform(y_test[['Department']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Create a OneHotEncoder for the Attrition column
att_OHE = OneHotEncoder(sparse=False)

# Fit the encoder to the training data
att_OHE.fit(y_train[['Attrition']])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_att_encoded = att_OHE.transform(y_train[['Attrition']])
y_test_att_encoded = att_OHE.transform(y_test[['Attrition']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
num_col = X_train_scaled.shape[1]

# Create the input layer
input_layer = layers.Input(shape=(num_col,))

# Create at least two shared layers
shared_layer1 = layers.Dense(64, activation='relu')(input_layer)
shared_layer2 = layers.Dense(32, activation='relu')(shared_layer1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer

# Create the hidden layer
dept_hidden_layer = layers.Dense(16, activation='relu')(shared_layer2)

# Create the output layer
dept_output_layer = layers.Dense(y_train_encoded.shape[1], activation='softmax', name='dept_output')(dept_hidden_layer)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer
att_hidden_layer = layers.Dense(16, activation='relu')(shared_layer2)

# Create the output layer
att_output_layer = layers.Dense(y_train_att_encoded.shape[1], activation='sigmoid', name='att_output')(att_hidden_layer)

# %%
# Create the model
model = Model(inputs=input_layer, outputs=[dept_output_layer, att_output_layer])

# Compile the model
model.compile(optimizer='adam',
              loss={'dept_output': 'categorical_crossentropy', 'att_output': 'categorical_crossentropy'},
              metrics={'dept_output': 'accuracy', 'att_output': 'accuracy'})

# Summarize the model
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 19)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 64)             │          1,280 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 32)             │          2,080 │ dense_10[0][0]         │
# ...

# %%
# Train the model
att_model = model.fit(
    X_train_scaled,
    {'dept_output': y_train_encoded, 'att_output': y_train_att_encoded},
    epochs=100,
    batch_size=32,
    validation_data=(X_test_scaled, {'dept_output': y_test_encoded, 'att_output': y_test_att_encoded}),
    verbose=1
)
# Out:
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - att_output_accuracy: 0.8344 - dept_output_accuracy: 0.6683 - loss: 1.4250 - val_att_output_accuracy: 0.8673 - val_dept_output_accuracy: 0.9116 - val_loss: 0.8633
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - att_output_accuracy: 0.8232 - dept_output_accuracy: 0.9276 - loss: 0.7724 - val_att_output_accuracy: 0.8673 - val_dept_output_accuracy: 0.9354 - val_loss: 0.5553
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - att_output_accuracy: 0.8400 - dept_output_accuracy: 0.9450 - loss: 0.5136 - val_att_output_accuracy: 0.8741 - val_dept_output_accuracy: 0.9660 - val_loss: 0.4869
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - att_output_accuracy: 0.8355 - dept_output_accuracy: 0.9703 - loss: 0.4658 - val_att_output_accuracy: 0.8673 - val_dept_output_accuracy: 0.9762 - val_loss: 0.4585
# Epoch 5/100
# ...

# %%
# Evaluate the model with the testing data
evaluation = model.evaluate(X_test_scaled,
    {'dept_output': y_test_encoded, 'att_output': y_test_att_encoded},
    verbose=1)

# Print the evaluation list to understand its structure
print(evaluation)

# Extract the specific metrics
test_loss = evaluation[0]
department_output_loss = evaluation[1]
attrition_output_loss = evaluation[2]

print(f"Test Loss: {test_loss}")
print(f"Test Department Output Loss: {department_output_loss}")
print(f"Test Attrition Output Loss: {attrition_output_loss}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - att_output_accuracy: 0.8022 - dept_output_accuracy: 0.9601 - loss: 2.0335
# [1.7306952476501465, 0.8163265585899353, 0.9489796161651611]
# Test Loss: 1.7306952476501465
# Test Department Output Loss: 0.8163265585899353
# Test Attrition Output Loss: 0.9489796161651611

# %%
# Calculate accuracy for the department output
dept_pred = model.predict(X_test_scaled)[0]
dept_accuracy = np.mean(np.argmax(dept_pred, axis=1) == np.argmax(y_test_encoded, axis=1))

# Calculate accuracy for the attrition output
att_pred = model.predict(X_test_scaled)[1]
att_accuracy = np.mean(np.argmax(att_pred, axis=1) == np.argmax(y_test_att_encoded, axis=1))

# Print the accuracy for both department and attrition
print(f"Test Department Output Accuracy: {dept_accuracy}")
print(f"Test Attrition Output Accuracy: {att_accuracy}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test Department Output Accuracy: 0.9489795918367347
# Test Attrition Output Accuracy: 0.8163265306122449

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. I don't believe accuracy is the best metric for this dataset as it does not account for potential bias in the data, i.e., attrition data imbalance between those who stayed and those who quit. A classification report to provide more insight into the model's performance is warranted.
# 2. While i tested a number of differnet combinations of activation functions I landed on Softmax which was chosen for both department and attrition outputs as this activation is used for multi-class classification in the department_output and for attrition_output, despite being a binary classification, to get probabilities of each class. This allows us to interpret the outputs as the likelihood of each class, allowing better decision-making based on predicted probabilities.
# 3. A few wasy that the model might be improved is to add more layers or neurons, completing hyperparameter tuning, increasing the number of epochs and/or feature engineering.
